# %% [markdown]
# # Reference
# - __[Real Python](https://realpython.com/asteroids-game-python/)__

# %% [markdown]
# # Note: General

# %% [markdown]
# ![image.png](attachment:98f1e1ff-95b8-4391-8b2c-b420586a3faf.png)

# %% [markdown]
# # Note: game.py
# collidepoint()
# >test if a point is inside a rectangle <br>
# collidepoint(x, y) -> bool<br>
# collidepoint((x,y)) -> bool<br>
#
# ![image.png](attachment:a9b9fa1e-ab51-484c-a397-a565b25b75da.png)
#
# Collision Detection <br>
# ![image.png](attachment:4ab2b6a5-a025-49ed-a2a0-c659cf5ff81a.png)
#
# Bullet & Asteroid Collision <br>
# ![image.png](attachment:c55fed69-12a1-4f9d-8376-72762f57507e.png)

# %% [markdown]
# # Note: utils.py
#
# convert()
# > Purpose: Creates a new copy of the Surface with the pixel format changed. <br>
# convert(Surface=None) -> Surface<br>
# convert(depth, flags=0) -> Surface<br>
# convert(masks, flags=0) -> Surface<br>
#
# convert_alpha()
# > Purpose: Creates a new copy of the surface with the desired pixel format<br>
# convert_alpha(Surface) -> Surface<br>
# convert_alpha() -> Surface<br>
#
# ![image.png](attachment:71387213-775a-4f47-902a-185114297c02.png)

# %% [markdown]
# # Note: model.py
# pygame.sprite.collide_circle()
# > Collision detection between two sprites, using circles. <br>
# collide_circle(left, right) -> bool<br>
#
# pygame.math.Vector2
# > a 2-Dimensional Vector<br>
# Vector2() -> Vector2(0, 0)<br>
# Vector2(int) -> Vector2<br>
# Vector2(float) -> Vector2<br>
# Vector2(Vector2) -> Vector2<br>
# Vector2(x, y) -> Vector2<br>
# Vector2((x, y)) -> Vector2<br>
#
# rotate_ip()
# > rotates the vector by a given angle in degrees in place. <br>
# rotate_ip(angle) -> None<br>
#
# pygame.transform.rotozoom()
# > filtered scale and rotation<br>
# rotozoom(surface, angle, scale) -> Surface<br>
#
# angle_to()
# > calculates the angle to a given vector in degrees.<br>
# angle_to(Vector2) -> float<br>
#
# get_size()
# > returns the dimensions of the images being recorded<br>
# get_size() -> (width, height)<br>
#
# Source: Real Python<br>
# ![image.png](attachment:29bcfb13-0635-40f2-93b4-cca197ba3472.png)
#
# ![image.png](attachment:ab54d170-235f-4c74-a574-859653bec68b.png)
#
# ![image.png](attachment:0057863d-c229-4848-9cf3-f5dc6c5f8e36.png)
#
# ![image.png](attachment:fabdc8d9-6fd9-42d9-a644-43d8f8c78c9a.png)
#
# Source: Pygame Documentation<br>
# ![image.png](attachment:0abfcd5a-4176-4441-b00b-9987a9f1f92b.png)
#
# __[Callback Function ](https://www.askpython.com/python/built-in-methods/callback-functions-in-python)__
# ![image.png](attachment:0df4b20c-cae6-4d7c-9900-697bb98da43b.png)

# %% [markdown]
# # Input
# ![image.png](attachment:f6d609a8-7d5c-4abe-be12-600c43f7ec5f.png)
#
# # Output
# ![image.png](attachment:fb5746ea-dec5-46e2-8a9b-727afab6f320.png)
