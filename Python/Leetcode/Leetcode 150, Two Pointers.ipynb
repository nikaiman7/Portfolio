# %% [markdown]
# ## References
# - __[Leetcode: Top Interview 150](https://leetcode.com/studyplan/top-interview-150/)__
# - __[Github: mdmzfzl](https://github.com/mdmzfzl/NeetCode-Solutions?tab=readme-ov-file)__
# - __[Github: shrenik-jain](https://github.com/shrenik-jain/neetcode-solutions/tree/main)__

# %% [markdown]
# ## Valid Palindrome
# Question:
# > A phrase is a palindrome if, after converting all uppercase letters into lowercase letters and removing all non-alphanumeric <br>characters, it reads the same forward and backward. Alphanumeric characters include letters and numbers. <br>
#
# Example:
# > ![image.png](attachment:09cec02c-22ed-4306-8085-c09c02e098cf.png) <br>
#
# Key Idea:
# >  <br>

# %%
def isPalindrome(s: str) -> bool:
    # Filter out non-alphanumeric characters and convert to lowercase
    filtered_chars = ''.join(char.lower() for char in s if char.isalnum())
    # Check if the filtered string is the same as its reverse
    return filtered_chars == filtered_chars[::-1]

# Example usage
s = "A man, a plan, a canal: Panama"
print(isPalindrome(s))  # Output: True

s = "race a car"
print(isPalindrome(s))  # Output: False
# Out:
# True
# False

# %%
s = "A man, a plan, a canal: Panama"
filtered_chars = ''

for char in s:
    if char.isalnum():
        filtered_chars += char.lower()
    else:
        continue
print(f"""filtered_chars: {filtered_chars}, 
filtered_chars(reversed): {filtered_chars[::-1]},
isPalindrome: {filtered_chars == filtered_chars[::-1]}""")

# filtered_chars = ''.join(char.lower() for char in s if char.isalnum())
# Out:
# filtered_chars: amanaplanacanalpanama,
# filtered_chars(reversed): amanaplanacanalpanama,
# isPalindrome: True

# %% [markdown]
# ### Note
# ![image.png](attachment:1eb982d8-5485-4d09-bf71-68e2b69741a6.png)

# %% [markdown]
# ## Two Sum II - Input Array Is Sorted
# Question:
# > ![image.png](attachment:01122566-9aec-4b0a-ae6b-22474bc0df3a.png) <br>
#
# Example:
# > ![image.png](attachment:50778d16-72da-4b44-b560-d1a5de1a60d2.png) <br>
#
# Key Idea:
# >  <br>

# %%
def twoSum(numbers: list[int], target: int) -> list[int]:
    # Initialize two pointers
    left, right = 0, len(numbers) - 1
    
    while left < right:
        current_sum = numbers[left] + numbers[right]
        if current_sum == target:
            # Return 1-based indices
            return [left + 1, right + 1]
        elif current_sum < target:
            # Move the left pointer to increase the sum
            left += 1
        else:
            # Move the right pointer to decrease the sum
            right -= 1
    
    # If no solution is found (though the problem guarantees one)
    return []

# Example usage
numbers = [2, 7, 11, 15]
target = 9
print(twoSum(numbers, target)) 

numbers, target = [2,3,4], 6
print(twoSum(numbers, target))

numbers, target = [-1,0], -1
print(twoSum(numbers, target))
# Out:
# [1, 2]
# [1, 3]
# [1, 2]

# %%
numbers, target = [2, 7, 11, 15], 9
numbers, target = [2,3,4,5,6,7,8], 13

# Initialize two pointers
left, right = 0, len(numbers) - 1

while left < right:
    current_sum = numbers[left] + numbers[right]
    print(f"""number, left: {numbers[left]}, number, right: {numbers[right]}, number, sum: {current_sum}""")
    if current_sum == target:
        # Return 1-based indices
        print(f"Output: {[left + 1, right + 1]}")
        break 
    elif current_sum < target:
        # Move the left pointer to increase the sum
        left += 1
    else:
        # Move the right pointer to decrease the sum
        right -= 1
# Out:
# number, left: 2, number, right: 8, number, sum: 10
# number, left: 3, number, right: 8, number, sum: 11
# number, left: 4, number, right: 8, number, sum: 12
# number, left: 5, number, right: 8, number, sum: 13
# Output: [4, 7]

# %% [markdown]
# ### Note
# ![image.png](attachment:d7ff4e4a-20a4-4015-98d9-2c61f53c2fd7.png)

# %% [markdown]
# ## 3Sum
# Question:
# > ![image.png](attachment:93b9a9e7-8509-4e47-887b-1aa9fb71c629.png) <br>
#
# Example:
# > ![image.png](attachment:c3648625-0513-4c49-9d5c-adfaa7903d83.png)
#
# Key Idea:
# >  <br>

# %%
def threeSum(nums: list[int]) -> list[list[int]]:
    nums.sort()  # Sort the array
    print(f"Sorted array: {nums}")
    result = []
    
    for i in range(len(nums) - 2):
        # Skip duplicate numbers for the first element
        if i > 0 and nums[i] == nums[i - 1]:
            continue
        
        left, right = i + 1, len(nums) - 1  # Two pointers
        while left < right:
            total = nums[i] + nums[left] + nums[right]
            print(f"nums_index: {nums[i]}, nums_left: {nums[left]}, nums_right: {nums[right]}, total: {total}")
            
            if total == 0:
                result.append([nums[i], nums[left], nums[right]])
                left += 1
                right -= 1
                
                # Skip duplicates for the second and third elements
                while left < right and nums[left] == nums[left - 1]:
                    left += 1
                while left < right and nums[right] == nums[right + 1]:
                    right -= 1
            elif total < 0:
                left += 1  # Move the left pointer to increase the sum
            else:
                right -= 1  # Move the right pointer to decrease the sum
    
    return result

# Example usage
nums = [-1, 0, 1, 2, -1, -4]
print(threeSum(nums))  # Output: [[-1, -1, 2], [-1, 0, 1]]
# Out:
# Sorted array: [-4, -1, -1, 0, 1, 2]
# nums_index: -4, nums_left: -1, nums_right: 2, total: -3
# nums_index: -4, nums_left: -1, nums_right: 2, total: -3
# nums_index: -4, nums_left: 0, nums_right: 2, total: -2
# nums_index: -4, nums_left: 1, nums_right: 2, total: -1
# nums_index: -1, nums_left: -1, nums_right: 2, total: 0
# nums_index: -1, nums_left: 0, nums_right: 1, total: 0
# nums_index: 0, nums_left: 1, nums_right: 2, total: 3
# [[-1, -1, 2], [-1, 0, 1]]

# %% [markdown]
# ### Note
# ![image.png](attachment:0bab0033-c086-4005-8834-f36e2ae367f2.png)
# ![image.png](attachment:79c31fc5-8d00-4180-98bd-7cab31ecb1ae.png) <br>
# ![image.png](attachment:cc804358-2f13-4767-bc6e-57f116bc2f92.png)

# %% [markdown]
# ## Container With Most Water
# Question:
# >  ![image.png](attachment:3fefc3ad-4259-4a55-81d6-0f06e1de6d5e.png) <br>
#
# Example:
# > ![image.png](attachment:4626add7-e4d6-42c6-8517-6e14ef1a0ef6.png) <br>
#
# Key Idea:
# >  <br>

# %%
def maxArea(height: list[int]) -> int:
    left, right = 0, len(height) - 1  # Initialize two pointers
    max_water = 0  # Variable to store the maximum water

    while left < right:
        # Calculate the area between the two pointers
        current_water = (right - left) * min(height[left], height[right])
        # Update max_water if the current area is larger
        max_water = max(max_water, current_water)
        print(f"height, left: {height[left]}, height, right: {height[right]}, area, water: {current_water}, area, max: {max_water}")

        # Move the pointer pointing to the shorter line
        if height[left] < height[right]:
            left += 1
        else:
            right -= 1

    return max_water

# Example usage
height = [1,8,6,2,5,4,8,3,7]
print(maxArea(height))  # Output: 49
# Out:
# height, left: 1, height, right: 7, area, water: 8, area, max: 8
# height, left: 8, height, right: 7, area, water: 49, area, max: 49
# height, left: 8, height, right: 3, area, water: 18, area, max: 49
# height, left: 8, height, right: 8, area, water: 40, area, max: 49
# height, left: 8, height, right: 4, area, water: 16, area, max: 49
# height, left: 8, height, right: 5, area, water: 15, area, max: 49
# height, left: 8, height, right: 2, area, water: 4, area, max: 49
# height, left: 8, height, right: 6, area, water: 6, area, max: 49
# 49

# %% [markdown]
# ## Trapping Rain Water
# Question:
# > Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining. <br>
#
# Example:
# > ![image.png](attachment:6d90a71c-bb11-48b7-ab42-a1fb6415d555.png) <br>
#
# Key Idea:
# >  <br>

# %%
def trap(height: list[int]) -> int:
    if not height:
        return 0

    left, right = 0, len(height) - 1
    left_max, right_max = 0, 0
    water = 0

    while left < right:
        if height[left] < height[right]:
            if height[left] >= left_max:
                left_max = height[left]
            else:
                water += left_max - height[left]
            left += 1
        else:
            if height[right] >= right_max:
                right_max = height[right]
            else:
                water += right_max - height[right]
            right -= 1

    return water

# Example usage
height = [0,1,0,2,1,0,1,3,2,1,2,1]
print(trap(height))  # Output: 6
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:75629756-5b9f-443d-ae79-c8e516f31119.png)
# ![image.png](attachment:4d2def28-8cac-48eb-b77e-58c8d2f69da0.png)

# %% [markdown]
# ## Title
# Question:
# >  <br>
#
# Example:
# > Input: <br>
# > Output: <br>
#
# Key Idea:
# >  <br>
