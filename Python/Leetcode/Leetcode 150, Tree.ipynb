# %% [markdown]
# ## References
# - __[Leetcode: Top Interview 150](https://leetcode.com/studyplan/top-interview-150/)__
# - __[Github: mdmzfzl](https://github.com/mdmzfzl/NeetCode-Solutions?tab=readme-ov-file)__
# - __[Github: shrenik-jain](https://github.com/shrenik-jain/neetcode-solutions/tree/main)__

# %% [markdown]
# ## Note
# - __[GeeksforGeeks: Introduction to Tree Data Structure](https://www.geeksforgeeks.org/introduction-to-tree-data-structure/)__
#
# ![image.png](attachment:e7f9f342-1da1-4783-97ae-34dc8eedc0f5.png)
# ![image.png](attachment:943803d5-fc1e-4456-a5ab-80fb474a9643.png)
# ![image.png](attachment:a53f196f-2552-4f0a-9b64-aff6286fe0e5.png)

# %% [markdown]
# ## Invert Binary Tree
# Question:
# > Given the root of a binary tree, invert the tree, and return its root. <br>
#
# Example:
# > ![image.png](attachment:c24f9920-c4de-4785-b87c-9187a1cd8dec.png)
#
# Key Idea:
# >  <br>

# %%
def build_tree(values):
    if not values:
        return None
    nodes = [TreeNode(val) if val is not None else None for val in values]
    for i, node in enumerate(nodes):
        if node:
            left_idx = 2 * i + 1
            right_idx = 2 * i + 2
            if left_idx < len(nodes):
                node.left = nodes[left_idx]
            if right_idx < len(nodes):
                node.right = nodes[right_idx]
    return nodes[0]

def tree_to_list(root):
    if not root:
        return []
    result, queue = [], [root]
    while queue:
        node = queue.pop(0)
        if node:
            result.append(node.val)
            queue.append(node.left)
            queue.append(node.right)
        else:
            result.append(None)
    while result and result[-1] is None:
        result.pop()  # Remove trailing None values
    return result

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def invertTree(self, root: TreeNode) -> TreeNode:
        if not root:
            return None
        
        stack = [root]
        
        while stack:
            current = stack.pop()
            
            # Swap the left and right children
            current.left, current.right = current.right, current.left
            
            # Add the children to the stack if they exist
            if current.left:
                stack.append(current.left)
            if current.right:
                stack.append(current.right)
        
        return root

# %%
values = [4, 2, 7, 1, 3, 6, 9]
root = build_tree(values)

solution = Solution()
inverted_root = solution.invertTree(root)

print(tree_to_list(inverted_root))  # Output: [4, 7, 2, 9, 6, 3, 1]
# Out:
# [4, 7, 2, 9, 6, 3, 1]

# %% [markdown]
# ### Note
# ![image.png](attachment:f86dfbfb-3509-4afb-999f-538ec6cb673f.png) <br>
# ![image.png](attachment:1694e557-4548-44f3-b729-541710707cb6.png)<br>
# ![image.png](attachment:64b6f926-6c71-4c75-951e-bbc678133a3a.png)<br>
# ![image.png](attachment:b62b7f81-ca64-45f8-be26-d017fe244e4a.png)<br>
# ![image.png](attachment:c6c03960-2e0f-48a7-8c0b-b26fc6545674.png)<br>
# ![image.png](attachment:7c4827dc-0195-4d64-a227-a5d89a44f129.png)<br>
# ![image.png](attachment:8759b087-ec3f-4ad8-8a06-09592fe0f103.png)<br>
# ![image.png](attachment:f77f5c42-0ca8-42e6-8c51-332a788fb44d.png)<br>
# ![image.png](attachment:87707c81-2053-480a-9810-acbaa9b53403.png)<br>
# ![image.png](attachment:01391737-348a-437c-ad9c-ab4f2d71881f.png)<br>
# ![image.png](attachment:8809f771-99cd-4b75-87b1-7b0f6586fb56.png)<br>
# ![image.png](attachment:cb14e808-e8a3-46bb-a4a2-aa3b3008e6d4.png)<br>

# %% [markdown]
# ## Title
# Question:
# >  <br>
#
# Example:
# > Input: <br>
# > Output: <br>
#
# Key Idea:
# >  <br>
