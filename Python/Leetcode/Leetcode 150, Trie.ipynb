# %% [markdown]
# ## References
# - __[Leetcode: Top Interview 150](https://leetcode.com/studyplan/top-interview-150/)__
# - __[Github: mdmzfzl](https://github.com/mdmzfzl/NeetCode-Solutions?tab=readme-ov-file)__
# - __[Github: shrenik-jain](https://github.com/shrenik-jain/neetcode-solutions/tree/main)__

# %% [markdown]
# ## Note
# - __[Trie Data Structure](https://www.geeksforgeeks.org/introduction-to-trie-data-structure-and-algorithm-tutorials/)__
#
# ![image.png](attachment:78507297-3491-4b8e-a3e2-2873e03e01ab.png)
# ![image.png](attachment:b1db77fd-229e-41db-b179-cd1d4fcd4943.png)
# ![image.png](attachment:841bb248-fa8f-41df-9366-7055260d29da.png)
# ![image.png](attachment:efebb28b-2b81-4d69-86a9-f1d1193387ab.png)
# ![image.png](attachment:7e7d43b6-9d41-4173-821c-9df336007e43.png)
# ![image.png](attachment:50935cf0-439f-49a5-be70-c4a4c00cbdd2.png)

# %% [markdown]
# ## Title
# Question:
# >  <br>
#
# Example:
# > Input: <br>
# > Output: <br>
#
# Key Idea:
# >  <br>
