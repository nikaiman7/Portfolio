# %% [markdown]
# # Mad Libs Game
# - __[Giraffe Academy](https://www.giraffeacademy.com/programming-languages/python/building-a-mad-libs-game/)__

# %%
color      = input("Enter a color: ")
pluralNoun = input("Enter a plural noun: ")
celebrity  = input("Enter a celebrity: ")

print("Roses are", color)
print(pluralNoun + " are blue")
print("I love", celebrity)
# Out:
# Enter a color:  blue
# Enter a plural noun:  birds
# Enter a celebrity:  Mufassa
# Roses are blue
# birds are blue
# I love Mufassa

# %%
def mad_libs():
    print("Welcome to the Mad Libs Game!\n")
    print("Please provide words as prompted to fill in the story.\n")

    # Prompt the user for words
    adjective1 = input("Enter an adjective: ")
    noun1      = input("Enter a noun: ")
    verb1      = input("Enter a verb (past tense): ")
    adverb1    = input("Enter an adverb: ")
    adjective2 = input("Enter another adjective: ")
    noun2      = input("Enter another noun: ")
    verb2      = input("Enter another verb (present tense): ")
    adverb2    = input("Enter another adverb: ")

    # The Mad Libs template
    story = f"""
            Today I went to the zoo. I saw a {adjective1} {noun1} jumping up and down in its cage. 
            It {verb1} {adverb1} through the large tunnel and landed in front of a {adjective2} {noun2}. 
            The {noun2} then started to {verb2} {adverb2} into the sunset. What a day at the zoo!
            """

    # Print the final story
    print("\nHere is your Mad Libs story:\n")
    print(story)

if __name__ == "__main__":
    mad_libs()
# Out:
# Welcome to the Mad Libs Game!
#
# Please provide words as prompted to fill in the story.
# Enter an adjective:  strong
# Enter a noun:  lion
# Enter a verb (past tense):  jumping
# Enter an adverb:  dangerously
# Enter another adjective:  towering
# Enter another noun:  building
# Enter another verb (present tense):  showered
# Enter another adverb:  lightly
# Here is your Mad Libs story:
#
#
#             Today I went to the zoo. I saw a strong lion jumping up and down in its cage.
#             It jumping dangerously through the large tunnel and landed in front of a towering building.
#             The building then started to showered lightly into the sunset. What a day at the zoo!

# %% [markdown]
# ### NOTE
#
# ![image.png](attachment:1c2e8b4e-fcb9-4bc2-8c09-809720ac8f63.png)
