# %% [markdown]
# # Rock, Paper, Scissors
#
# - __[The Hello World Program](https://thehelloworldprogram.com/python/python-game-rock-paper-scissors/)__

# %%
from random import randint

#create a list of play options
t = ["Rock", "Paper", "Scissors"]

#assign a random play to the computer
computer = t[randint(0,2)]

#set player to False
player = False

while player == False:
#set player to True
    player = input("Rock, Paper, Scissors?")
    if player == computer:
        print("Tie!")
    elif player == "Rock":
        if computer == "Paper":
            print("You lose!", computer, "covers", player)
        else:
            print("You win!", player, "smashes", computer)
    elif player == "Paper":
        if computer == "Scissors":
            print("You lose!", computer, "cut", player)
        else:
            print("You win!", player, "covers", computer)
    elif player == "Scissors":
        if computer == "Rock":
            print("You lose...", computer, "smashes", player)
        else:
            print("You win!", player, "cut", computer)
    else:
        print("That's not a valid play. Check your spelling!")
        
#player was set to True, but we want it to be False so the loop ends
player = False
computer = t[randint(0,2)]
# Out:
# Rock, Paper, Scissors? Rock
# You win! Rock smashes Scissors

# %%
from random import randint

#create a list of play options
t = ["Rock", "Paper", "Scissors"]

#assign a random play to the computer
computer = t[randint(0,2)]

#set player to False
player = False

while player == False:  
    #set player to True
    player  = input("Rock, Paper, Scissors?")
    
    #check input
    if player not in t:
        print("That's not a valid play. Check your spelling!")
        player = False
    else:
        player = True
        #compare outputs for both
        if player == computer:
            print("Tie!")
        elif (player == "Rock"     and computer == "Scissors") or \
             (player == "Paper"    and computer == "Rock") or \
             (player == "Scissors" and computer == "Paper"):
            print("You win!")
        else:
            print("You lose!")
# Out:
# Rock, Paper, Scissors? bubu
# That's not a valid play. Check your spelling!
# Rock, Paper, Scissors? Rock
# You lose!

# %%
import random

def get_user_choice():
    print("\nChoose your option:")
    print("1: Rock")
    print("2: Paper")
    print("3: Scissors")
    try:
        choice = int(input("Enter the number corresponding to your choice (1-3): "))
        if choice in [1, 2, 3]:
            return choice
        else:
            print("Invalid choice! Please choose a number between 1 and 3.")
            return get_user_choice()
    except ValueError:
        print("Invalid input! Please enter a number.")
        return get_user_choice()

def get_computer_choice():
    return random.choice([1, 2, 3])

def determine_winner(user_choice, computer_choice):
    choices = {1: "Rock", 2: "Paper", 3: "Scissors"}
    print(f"\nYou chose: {choices[user_choice]}")
    print(f"Computer chose: {choices[computer_choice]}")

    if user_choice == computer_choice:
        return "It's a tie!"
    elif (user_choice == 1 and computer_choice == 3) or \
         (user_choice == 2 and computer_choice == 1) or \
         (user_choice == 3 and computer_choice == 2):
        return "You win!"
    else:
        return "You lose!"

def play_game():
    print("Welcome to Rock, Paper, Scissors!")
    while True:
        user_choice = get_user_choice()
        computer_choice = get_computer_choice()
        result = determine_winner(user_choice, computer_choice)
        print(result)

        play_again = input("\nDo you want to play again? (yes/no): ").strip().lower()
        if play_again not in ['yes', 'y']:
            print("Thanks for playing! Goodbye!")
            break

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Rock, Paper, Scissors!
#
# Choose your option:
# 1: Rock
# 2: Paper
# 3: Scissors
# Enter the number corresponding to your choice (1-3):  2
# You chose: Paper
# Computer chose: Scissors
# You lose!
# Do you want to play again? (yes/no):  y
# Choose your option:
# 1: Rock
# 2: Paper
# 3: Scissors
# Enter the number corresponding to your choice (1-3):  3
# You chose: Scissors
# Computer chose: Paper
# You win!
# Do you want to play again? (yes/no):  yes
# Choose your option:
# 1: Rock
# 2: Paper
# 3: Scissors
# Enter the number corresponding to your choice (1-3):  3
# You chose: Scissors
# Computer chose: Rock
# You lose!
# Do you want to play again? (yes/no):  ye
# Thanks for playing! Goodbye!

# %% [markdown]
# ### NOTE
#
# ![image.png](attachment:167234b9-149f-4ec3-a2eb-a8132f1e6e7d.png)
#
# ![image.png](attachment:95606037-0e6a-4bec-9f2b-e53e193249dc.png)
#
# ![image.png](attachment:e164881a-a629-419e-8cb7-31c7f80372db.png)
